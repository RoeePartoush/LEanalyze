# %%
import imexam
import os

# %%
#viewer = imexam.connect(path='/Users/roeepartoush/opt/anaconda3/envs/astroconda/bin/ds9')
viewer = imexam.connect(path='/Applications/SAOImageDS9.app/Contents/MacOS/ds9')

# %%
files=[]
# root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/ut120919/4/'
root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED'
# root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/plhstproc/tyc4519/5/'
for file in os.listdir(root):
    if file.endswith('sw.fits'): files.append(os.path.join(root,file))

# %%
files[17]
# Out:
# '/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED/tyc4519.VR.20150814.64481_stch_5.sw.fits'

# %%
#import matplotlib.pyplot as plt

#root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED/'
#viewer.load_fits(os.path.join(root,'tyc4519.VR.20140827.105550_stch_5.sw.fits'))
viewer.load_fits(files[17])
viewer.scale()
#plt.ion()
#plt.figure()
viewer.imexam()
# Out:
# Press 'q' to quit
#
# 2 Make the next plot in a new window
# a Aperture sum, with radius region_size
# b Return the 2D gauss fit center of the object
# c Return column plot
# d Return the Center of Mass fit center of the object
# e Return a contour plot in a region around the cursor
# g Return curve of growth plot
# h Return a histogram in the region around the cursor
# j 1D [Gaussian1D default] line fit
# k 1D [Gaussian1D default] column fit
# l Return line plot
# m Square region stats, in [region_size],default is median
# r Return the radial profile plot
# s Save current figure to disk as [plot_name]
# t Make a fits image cutout using pointer location
# w Display a surface plot around the cursor location
# x Return x,y,value of pixel
# y Return x,y,value of pixel
# Current image /Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED/tyc4519.VR.20150814.64481_stch_5.sw.fits
# xc=2009.2884	yc=1011.2390
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 2008.00        1011.00        5              1.5e+04        1.5e+01        801.527        1.77,1.85
# 2009.2884374683463 1011.2389984659189 24.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d1e45cf4e130> in <module>
#       7 #plt.ion()
#       8 #plt.figure()
# ----> 9 viewer.imexam()
#
# ~/opt/anaconda3/envs/astroconda/lib/python3.6/site-packages/imexam/connect.py in imexam(self)
#     148                 self._run_event_imexam()
#     149             else:
# --> 150                 self._run_imexam()
#     151         else:
#     152             warnings.warn("No valid image loaded in viewer")
#
# ~/opt/anaconda3/envs/astroconda/lib/python3.6/site-packages/imexam/connect.py in _run_imexam(self)
#     240                 # interface.
#     241                 try:
# --> 242                     x, y, current_key = self.readcursor()
#     243                     if current_key in ["Left", "Right", "Up", "Down"]:
#     244                         if current_key == "Left":
#
# ~/opt/anaconda3/envs/astroconda/lib/python3.6/site-packages/imexam/connect.py in readcursor(self)
#     301         in the form of x,y,str with array offset
#     302         """
# --> 303         return self.window.readcursor()
#     304
#     305     def alignwcs(self, **kwargs):
#
# ~/opt/anaconda3/envs/astroconda/lib/python3.6/site-packages/imexam/ds9_viewer.py in readcursor(self)
#     699             raise ValueError("Outside of data range")
#     700
# --> 701         k, x, y = xpa_string.split()
#     702
#     703         # ds9 is returning 1 based array, set to 0-based since
#
# ValueError: not enough values to unpack (expected 3, got 0)
