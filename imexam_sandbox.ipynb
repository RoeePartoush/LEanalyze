# %%
import imexam
import os

# %%
imexam.list_active_ds9()

# %%
#viewer = imexam.connect(path='/Users/roeepartoush/opt/anaconda3/envs/astroconda/bin/ds9')
#viewer = imexam.connect(path='/Applications/SAOImageDS9.app/Contents/MacOS/ds9')
viewer = imexam.connect(viewer='ginga')#'7f000001:52384')

# %%
files=[]
# root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/ut120919/4/'
# root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED'
# root='/Users/roeepartoush/Documents/Research/Data/DOWNLOAD/plhstproc/tyc4419/1/'
#for file in os.listdir(root):
#    if file.endswith('.fits'):
#        files.append(os.path.join(root,file))
root = '/Users/roeepartoush/Documents/Research/Data/swarp_test/tycA1/'
files1=['20120118/tyc4419_tyc4519_20120118_coadd.fits',
        '20120626/tyc4419_tyc4519_20120626_coadd.fits',
        'KECK/tyc4419_1.R.r120918_0182_4.hdrfix_CORRECTED_DEG_MJD.sw._NOT_REALLY_coadd.fits',
        '20130109/tyc4419_tyc4519_20130109_coadd.fits',
        '20130609/tyc4419_tyc4519_20130609_coadd.fits',
        '20130826/tyc4419_tyc4519_20130826_coadd.fits',
        'KECK/tyc4419_1_DEIMOS_5_6_coadd.fits',
        '20131202/tyc4419_tyc4519_20131202_coadd.fits',
        'KECK/tyc4419_1_g_LRIS_131228_coadd.fits',
        'KECK/tyc4419_1_R_LRIS_131228_coadd.fits',
        '20140226/tyc4419_tyc4519_20140226_coadd.fits',
        '20140531/tyc4419_tyc4519_20140531_coadd.fits',
        '20140621/tyc4419_tyc4519_20140621_coadd.fits',
        '20140827/tyc4419_tyc4519_20140827_coadd.fits',
        '20140923/tyc4419_tyc4519_20140923_coadd.fits']
for file in files1:
    files.append(root+file)

# %%
file# = files[1]
# Out:
# '20140923/tyc4419_tyc4519_20140923_coadd.fits'

# %%
#viewer.exam.aper_phot_pars
#viewer.exam.aper_phot_pars#['radius']=[14, 'Radius of aperture for star flux']
viewer.exam.aper_phot_pars#['radius']=[14, 'Radius of aperture for star flux']
#viewer.exam.curve_of_growth_pars#['rplot']=[20.0, 'Plotting radius in pixels']

# %%
#import matplotlib.pyplot as plt
#viewer = imexam.connect(path='/Applications/SAOImageDS9.app/Contents/MacOS/ds9')
#root='/Users/roeep rtoush/Documents/Research/Data/DOWNLOAD/armin/leKeck/tyc4419a1/FIXED/'
#viewer.load_fits(os.path.join(root,'tyc4519.VR.20140827.105550_stch_5.sw.fits'))
viewer.load_fits(os.path.join(root,file))
viewer.scale()
#plt.ion()
#plt.figure()
viewer.imexam()
# Out:
# 2 Make the next plot in a new window
# a Aperture sum, with radius region_size
# b Return the 2D gauss fit center of the object
# c Return column plot
# d Return the Center of Mass fit center of the object
# e Return a contour plot in a region around the cursor
# g Return curve of growth plot
# h Return a histogram in the region around the cursor
# j 1D [Gaussian1D default] line fit
# k 1D [Gaussian1D default] column fit
# l Return line plot
# m Square region stats, in [region_size],default is median
# r Return the radial profile plot
# s Save current figure to disk as [plot_name]
# t Make a fits image cutout using pointer location
# w Display a surface plot around the cursor location
# x Return x,y,value of pixel
# y Return x,y,value of pixel
#
# Press the i key in the graphics window for access                  to imexam keys, or q to exit
#
# read: a at 2033.0, 1051.0
# xc=2033.3248	yc=1054.7561
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 2033.00        1051.00        5              3.3e+01        2.1e+01        -0.487         0.00,2.95
# 2033.3248305256038 1054.756129061844 24.0
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# read: a at 1965.0, 1035.0
# xc=1959.0389	yc=1032.9394
# /opt/anaconda3/lib/python3.7/site-packages/imexam/imexamine.py:633: RuntimeWarning: invalid value encountered in log10
#   mag = magzero - 2.5 * (np.log10(total_flux))
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 1965.00        1035.00        5              -4.5e+02       nan            7.586          0.00,1.90
# 1959.038894263576 1032.939411640732 24.0
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# read: control_l at 1975.0, 1089.0
# read: shift_l at 1975.0, 1089.0
# read: a at 2141.0, 920.0
# xc=2139.5774	yc=919.7438
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 2141.00        920.00         5              5.5e+02        1.8e+01        2.992          1.44,1.31
# 2139.577426684122 919.7437710717073 24.0
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# read: control_l at 2141.0, 920.0
# read: control_l at 2125.0, 926.0
# read: shift_l at 2125.0, 926.0
# read: control_l at 2140.0, 920.0
# read: shift_l at 2140.0, 920.0
# read: control_l at 2140.0, 920.0
# read: shift_l at 2140.0, 921.0
# read: i at 2077.0, 1007.0
# read: i at 2077.0, 1007.0
# read: alt_l at 2077.0, 1007.0
# read: control_l at 2077.0, 1007.0
# read: shift_l at 2077.0, 1007.0
# read: a at 1951.0, 989.0
# xc=1948.0737	yc=988.0920
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 1951.00        989.00         5              1.2e+03        1.7e+01        0.790          1.48,1.24
# 1948.073666849515 988.0920471432282 24.0
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# read: control_l at 1951.0, 989.0
# read: shift_l at 1951.0, 989.0
# read: control_l at 1948.0, 987.0
# read: shift_l at 1948.0, 987.0
# read: control_l at 1949.0, 987.0
# read: shift_l at 1949.0, 987.0
# read: control_l at 1949.0, 987.0
# read: control_l at 1949.0, 989.0
# read: i at 1948.0, 988.0
# read: a at 1948.0, 988.0
# xc=1948.0742	yc=988.0917
# x              y              radius         flux           mag(zpt=2.5e+01)              sky/pix        fwhm(x,y)
# 1948.00        988.00         5              1.2e+03        1.7e+01        0.790          1.50,1.25
# 1948.0741919949105 988.0917344405898 24.0
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# WARNING: AstropyDeprecationWarning: "ax" was deprecated in version 0.7 and will be removed in a future version. Use argument "axes" instead. [imexam.imexamine]
# read: control_l at 1948.0, 988.0
# read: shift_l at 1948.0, 988.0
# read: control_l at 1948.0, 988.0
# read: shift_l at 1948.0, 988.0
# read: control_l at 1948.0, 988.0
# read: shift_l at 1948.0, 988.0
# read: b at 1948.0, 988.0
# xc=1948.0742	yc=988.0917
# read: control_l at 1948.0, 988.0
# read: shift_l at 1948.0, 988.0
# read: e at 2015.0, 955.0
# contour centered at: 2015.0 955.0
# read: control_l at 2015.0, 955.0
# read: shift_l at 2015.0, 955.0
# read: e at 2126.0, 986.0
# contour centered at: 2126.0 986.0
# read: control_l at 2126.0, 986.0
# read: shift_l at 2126.0, 986.0
# read: e at 2110.0, 1028.0
# contour centered at: 2110.0 1028.0
# read: control_l at 2110.0, 1028.0
# read: shift_l at 2110.0, 1028.0
# read: control_l at 2025.0, 1099.0
# read: shift_l at 2025.0, 1099.0
# read: b at 2010.0, 1011.0
# xc=2009.1953	yc=1011.2752
# read: control_l at 2010.0, 1011.0
# read: shift_l at 2010.0, 1011.0
# read: b at 2011.0, 1012.0
# xc=2009.1953	yc=1011.2752
# read: control_l at 2011.0, 1012.0
# read: shift_l at 2011.0, 1012.0
# read: b at 2011.0, 1011.0
# xc=2009.1953	yc=1011.2752
# read: control_l at 2011.0, 1011.0
# read: shift_l at 2011.0, 1011.0
# read: control_l at 2011.0, 1011.0
# read: shift_l at 2011.0, 1011.0

# %%
viewer.close()
# Out:
# Stopped http server

# %%
viewer.imexam()
# Out:
# 2 Make the next plot in a new window
# a Aperture sum, with radius region_size
# b Return the 2D gauss fit center of the object
# c Return column plot
# d Return the Center of Mass fit center of the object
# e Return a contour plot in a region around the cursor
# g Return curve of growth plot
# h Return a histogram in the region around the cursor
# j 1D [Gaussian1D default] line fit
# k 1D [Gaussian1D default] column fit
# l Return line plot
# m Square region stats, in [region_size],default is median
# r Return the radial profile plot
# s Save current figure to disk as [plot_name]
# t Make a fits image cutout using pointer location
# w Display a surface plot around the cursor location
# x Return x,y,value of pixel
# y Return x,y,value of pixel
#
# Press the i key in the graphics window for access                  to imexam keys, or q to exit

# %%
viewer.load_fits(os.path.join(root,file))
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2014-09-24T07:30:10' from MJD-OBS'. [astropy.wcs.wcs]
