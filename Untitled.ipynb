# %%
# %% import
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt

#%matplotlib inline

from astropy.io import fits

# %%
# %% open fits file
hdu_list = fits.open('/Users/roeepartoush/Documents/Astropy/Data/Roee/tyc4419.VR.20150911.165399_R.20150211.157400_2.diff.fits')
hdu_list.info()

# %% get image
image_data = hdu_list[0].data

print(type(image_data))
print(image_data.shape)

hdu_list.close()
# Out:
# Filename: /Users/roeepartoush/Documents/Astropy/Data/Roee/tyc4419.VR.20150911.165399_R.20150211.157400_2.diff.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     175   (4200, 2200)   int16
# <class 'numpy.ndarray'>
# (2200, 4200)

# %%
# %% statistics
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))

print(type(image_data.flatten()))
image_data_tmp = image_data
image_data_tmp[image_data>10] = 10
image_data_tmp[image_data<-10] = -10

histogram = plt.hist(image_data_tmp.flatten(), bins='auto')
# Out:
# Min: -1758
# Max: 1137
# Mean: 0.2714668831168831
# Stdev: 17.35954699145947
# <class 'numpy.ndarray'>

# %%
f1 = plt.figure()
plt.imshow(image_data_tmp, cmap='gray')
plt.colorbar()
